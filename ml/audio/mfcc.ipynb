# %%
import pandas as pd
df1=pd.read_csv('/content/mfcc_emotion.csv')
df2=pd.read_csv('/content/mfcc_filepath_emotion.csv')
df3=pd.read_csv('/content/mfcc_updated_emotion.csv')
print(df1.head())
print(df2.head())
print(df3.head())
# Out:
#       mfcc_1     mfcc_2    mfcc_3     mfcc_4    mfcc_5    mfcc_6    mfcc_7  \
# 0 -670.19543  65.063850  0.888954  14.715979  9.182165  0.660575 -3.846836
# 1 -660.23035  63.325817 -2.630457  17.983355  9.407703 -0.981498 -2.324698
# 2 -661.96450  66.655870 -0.932158  14.899042  5.324703  0.474343 -3.346651
# 3 -657.72235  65.035190  3.148672  15.666511  7.582657  2.628087 -1.850069
# 4 -694.57960  72.531715  3.104562  17.112118  9.077339  1.836256 -4.146086
#
#      mfcc_8     mfcc_9   mfcc_10  ...   mfcc_32   mfcc_33   mfcc_34   mfcc_35  \
# 0 -3.583946 -12.959006 -3.300133  ... -2.504727 -3.151507 -2.190899 -3.801760
# 1 -6.848032 -14.133670 -2.200332  ... -3.113372 -2.556752 -2.935112 -3.654962
# 2 -7.102525 -12.873403 -5.088379  ... -2.643650 -2.937167 -2.361648 -3.345105
# 3 -7.477578 -11.976265 -4.458463  ... -2.849611 -3.591487 -3.104016 -3.495707
# 4 -4.797152 -11.764125 -5.925480  ... -1.405873 -2.290345 -2.879143 -2.069092
#
# ...

# %%
df1.shape
# Out:
# (1440, 41)

# %%
df3.shape
# Out:
# (1440, 42)

# %%
df1.columns
# Out:
# Index(['mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7',
#        'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13',
#        'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19',
#        'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25',
#        'mfcc_26', 'mfcc_27', 'mfcc_28', 'mfcc_29', 'mfcc_30', 'mfcc_31',
#        'mfcc_32', 'mfcc_33', 'mfcc_34', 'mfcc_35', 'mfcc_36', 'mfcc_37',
#        'mfcc_38', 'mfcc_39', 'mfcc_40', 'emotion'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5',
#        'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12',
#        'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18',
#        'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24',
#        'mfcc_25', 'mfcc_26', 'mfcc_27', 'mfcc_28', 'mfcc_29', 'mfcc_30',
#        'mfcc_31', 'mfcc_32', 'mfcc_33', 'mfcc_34', 'mfcc_35', 'mfcc_36',
#        'mfcc_37', 'mfcc_38', 'mfcc_39', 'mfcc_40', 'emotion'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# mfcc_1     0
# mfcc_2     0
# mfcc_3     0
# mfcc_4     0
# mfcc_5     0
# mfcc_6     0
# mfcc_7     0
# mfcc_8     0
# mfcc_9     0
# mfcc_10    0
# mfcc_11    0
# mfcc_12    0
# mfcc_13    0
# mfcc_14    0
# mfcc_15    0
# mfcc_16    0
# mfcc_17    0
# mfcc_18    0
# mfcc_19    0
# mfcc_20    0
# mfcc_21    0
# mfcc_22    0
# mfcc_23    0
# mfcc_24    0
# mfcc_25    0
# mfcc_26    0
# mfcc_27    0
# mfcc_28    0
# mfcc_29    0
# mfcc_30    0
# mfcc_31    0
# mfcc_32    0
# mfcc_33    0
# mfcc_34    0
# mfcc_35    0
# mfcc_36    0
# mfcc_37    0
# mfcc_38    0
# mfcc_39    0
# mfcc_40    0
# emotion    0
# dtype: int64

# %%
df1["emotion"].value_counts()
# Out:
# emotion
# calm        192
# happy       192
# sad         192
# angry       192
# disgust     192
# fear        192
# surprise    192
# neutral      96
# Name: count, dtype: int64

# %%
df3["emotion"].value_counts()
# Out:
# emotion
# neutral     288
# happy       192
# sad         192
# angry       192
# fear        192
# disgust     192
# surprise    192
# Name: count, dtype: int64

# %%
df=pd.read_csv('/content/mfcc_updated_emotion.csv')

# %%
df.shape
# Out:
# (1440, 42)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5',
#        'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12',
#        'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18',
#        'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24',
#        'mfcc_25', 'mfcc_26', 'mfcc_27', 'mfcc_28', 'mfcc_29', 'mfcc_30',
#        'mfcc_31', 'mfcc_32', 'mfcc_33', 'mfcc_34', 'mfcc_35', 'mfcc_36',
#        'mfcc_37', 'mfcc_38', 'mfcc_39', 'mfcc_40', 'emotion'],
#       dtype='object')

# %%
df=df.drop(columns=["Unnamed: 0"])

# %%
df.columns
# Out:
# Index(['mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7',
#        'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13',
#        'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19',
#        'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25',
#        'mfcc_26', 'mfcc_27', 'mfcc_28', 'mfcc_29', 'mfcc_30', 'mfcc_31',
#        'mfcc_32', 'mfcc_33', 'mfcc_34', 'mfcc_35', 'mfcc_36', 'mfcc_37',
#        'mfcc_38', 'mfcc_39', 'mfcc_40', 'emotion'],
#       dtype='object')

# %%
df["emotion"].nunique()
# Out:
# 7

# %%
df["emotion"].unique()
# Out:
# array(['neutral', 'happy', 'sad', 'angry', 'fear', 'disgust', 'surprise'],
#       dtype=object)

# %%
df.describe()
# Out:
#             mfcc_1       mfcc_2       mfcc_3       mfcc_4       mfcc_5  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean   -546.401637    57.581533    -7.266180     8.374569    -0.320560
# std     106.812150    18.194479    14.904511     9.045522    10.022709
# min    -804.965800   -10.567434   -62.752230   -27.504230   -33.458603
# 25%    -624.946487    45.735270   -16.250512     2.394004    -7.640241
# 50%    -554.856325    58.278963    -6.285933     8.662679     0.095550
# 75%    -477.640625    70.244129     3.338237    14.390707     7.369944
# max    -203.711270   109.969960    29.491150    35.584164    24.183680
#
#             mfcc_6       mfcc_7       mfcc_8       mfcc_9      mfcc_10  ...  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000  ...
# mean     -6.621282    -7.542681   -11.206328    -8.867225    -3.096140  ...
# std       8.148070     6.908520     6.278792     5.468671     4.597727  ...
# ...

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (1439, 41)

# %%
df.describe()
# Out:
#             mfcc_1       mfcc_2       mfcc_3       mfcc_4       mfcc_5  \
# count  1439.000000  1439.000000  1439.000000  1439.000000  1439.000000
# mean   -546.371755    57.562689    -7.266946     8.371654    -0.325747
# std     106.843262    18.186742    14.909664     9.047990    10.024259
# min    -804.965800   -10.567434   -62.752230   -27.504230   -33.458603
# 25%    -625.082875    45.724150   -16.254229     2.393524    -7.640268
# 50%    -554.556400    58.278614    -6.291183     8.646994     0.092926
# 75%    -477.624750    70.147175     3.346521    14.397789     7.373447
# max    -203.711270   109.969960    29.491150    35.584164    24.183680
#
#             mfcc_6       mfcc_7       mfcc_8       mfcc_9      mfcc_10  ...  \
# count  1439.000000  1439.000000  1439.000000  1439.000000  1439.000000  ...
# mean     -6.621391    -7.540475   -11.206373    -8.871896    -3.098483  ...
# std       8.150901     6.910415     6.280974     5.467698     4.598465  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1439 entries, 0 to 1439
# Data columns (total 41 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mfcc_1   1439 non-null   float64
#  1   mfcc_2   1439 non-null   float64
#  2   mfcc_3   1439 non-null   float64
#  3   mfcc_4   1439 non-null   float64
#  4   mfcc_5   1439 non-null   float64
#  5   mfcc_6   1439 non-null   float64
#  6   mfcc_7   1439 non-null   float64
#  7   mfcc_8   1439 non-null   float64
#  8   mfcc_9   1439 non-null   float64
#  9   mfcc_10  1439 non-null   float64
#  10  mfcc_11  1439 non-null   float64
#  11  mfcc_12  1439 non-null   float64
#  12  mfcc_13  1439 non-null   float64
#  13  mfcc_14  1439 non-null   float64
#  14  mfcc_15  1439 non-null   float64
#  15  mfcc_16  1439 non-null   float64
#  16  mfcc_17  1439 non-null   float64
#  17  mfcc_18  1439 non-null   float64
#  18  mfcc_19  1439 non-null   float64
#  19  mfcc_20  1439 non-null   float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.drop("emotion",axis=1).corr())
plt.show()

# %%
x=df.drop("emotion",axis=1)
y=df["emotion"]

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
le=LabelEncoder()
sc=StandardScaler()
x_scaled=sc.fit_transform(x)
y_scaled=le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(
    x_scaled,y_scaled,test_size=0.2,random_state=42,stratify=y_scaled
)

# %%
from sklearn.svm import SVC
svm_model=SVC(
    kernel='rbf',
    C=10,
    gamma='scale'
)

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC(C=10)

# %%
from sklearn.metrics import accuracy_score
y_pred=svm_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.7534722222222222

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[31  3  2  0  0  2  1]
#  [ 1 27  2  3  2  1  2]
#  [ 0  1 30  2  1  2  2]
#  [ 1  2  3 24  2  2  4]
#  [ 0  1  0  2 55  0  0]
#  [ 1  2  3  2  8 23  0]
#  [ 4  3  1  1  1  1 27]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred,target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.82      0.79      0.81        39
#      disgust       0.69      0.71      0.70        38
#         fear       0.73      0.79      0.76        38
#        happy       0.71      0.63      0.67        38
#      neutral       0.80      0.95      0.87        58
#          sad       0.74      0.59      0.66        39
#     surprise       0.75      0.71      0.73        38
#
#     accuracy                           0.75       288
#    macro avg       0.75      0.74      0.74       288
# weighted avg       0.75      0.75      0.75       288

# %%
from sklearn.neural_network import MLPClassifier
mlp_model=MLPClassifier(
    hidden_layer_sizes=(128,64),
    max_iter=500,
    random_state=42
)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred=svm_model.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred,target_names=le.classes_))
# Out:
# 0.7534722222222222
# [[31  3  2  0  0  2  1]
#  [ 1 27  2  3  2  1  2]
#  [ 0  1 30  2  1  2  2]
#  [ 1  2  3 24  2  2  4]
#  [ 0  1  0  2 55  0  0]
#  [ 1  2  3  2  8 23  0]
#  [ 4  3  1  1  1  1 27]]
#               precision    recall  f1-score   support
#
#        angry       0.82      0.79      0.81        39
#      disgust       0.69      0.71      0.70        38
#         fear       0.73      0.79      0.76        38
#        happy       0.71      0.63      0.67        38
#      neutral       0.80      0.95      0.87        58
#          sad       0.74      0.59      0.66        39
#     surprise       0.75      0.71      0.73        38
#
#     accuracy                           0.75       288
#    macro avg       0.75      0.74      0.74       288
# weighted avg       0.75      0.75      0.75       288

# %%
mlp_model.fit(x_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=500, random_state=42)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred=mlp_model.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred,target_names=le.classes_))
# Out:
# 0.6736111111111112
# [[29  3  1  1  0  3  2]
#  [ 5 18  3  4  3  1  4]
#  [ 0  0 24  6  1  4  3]
#  [ 1  1  3 22  2  3  6]
#  [ 0  1  1  1 53  2  0]
#  [ 0  2  1  4  8 24  0]
#  [ 3  3  2  1  2  3 24]]
#               precision    recall  f1-score   support
#
#        angry       0.76      0.74      0.75        39
#      disgust       0.64      0.47      0.55        38
#         fear       0.69      0.63      0.66        38
#        happy       0.56      0.58      0.57        38
#      neutral       0.77      0.91      0.83        58
#          sad       0.60      0.62      0.61        39
#     surprise       0.62      0.63      0.62        38
#
#     accuracy                           0.67       288
#    macro avg       0.66      0.66      0.66       288
# weighted avg       0.67      0.67      0.67       288

# %%
import librosa
import numpy as np
filepath='/content/03-01-08-02-02-02-02.wav'
audio,sr=librosa.load(filepath,duration=3,offset=0.5)
mfcc=librosa.feature.mfcc(y=audio,sr=sr,n_mfcc=40)
mfcc_scaled=np.mean(mfcc.T,axis=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
mfcc_scaler=sc.fit_transform([mfcc_scaled])

# %%
prediction=svm_model.predict(mfcc_scaler)

# %%
print(prediction)
# Out:
# [6]

# %%
print(le.classes_)
# Out:
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']

# %%
print(le.classes_[prediction])
# Out:
# ['surprise']

# %%
print(le.inverse_transform(prediction))
# Out:
# ['surprise']

# %%
print(le.classes_[mlp_model.predict(mfcc_scaler)])
# Out:
# ['surprise']

# %%
import joblib
joblib.dump(svm_model,'audio_svm_model.pkl')
joblib.dump(mlp_model,'audio_mlp_model.pkl')
joblib.dump(le,'audio_labelencoder.pkl')
joblib.dump(sc,'audio_standardscaler.pkl')
# Out:
# ['audio_standardscaler.pkl']

# %%
from google.colab import files
files.download('audio_svm_model.pkl')
files.download('audio_mlp_model.pkl')
files.download('audio_labelencoder.pkl')
files.download('audio_standardscaler.pkl')
